# %% [markdown]
# <a href="https://colab.research.google.com/github/crisconanfelix12-png/Tugas-1---Pemograman-Dasar/blob/main/tugas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata Saya
nama = "Cris"
umur = 26
jurusan = "RPE"
semester = 3
matakuliah = 'Pemerograman Dasar'
alamat = "Citramas"
status_lulus = False

print (nama)
print (umur)
print (jurusan)
print (semester)
print (matakuliah)
print (alamat)
print (status_lulus)
# Out:
# Cris
# 26
# RPE
# 3
# Pemerograman Dasar
# Citramas
# False
